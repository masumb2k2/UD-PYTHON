# %% [markdown]
# # Function in Python

# %%
# Syntax of function
def function_name(Paranmeter):
    '''docstring'''
    # function body
    return Expression

# %%
# why function
def even_or_odd(num):
    '''this function finds even or odd'''
    if num%2==0:
        print('even')
    else:
        print('odd')

# %%
even_or_odd(12)
# Out:
# even

# %%
## default parameters

def greet(name='guest'):
    print(f"Hello {name}")

greet('masum')
# Out:
# Hello masum

# %%
# positional and keyword argument
