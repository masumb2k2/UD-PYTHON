# %% [markdown]
# # Variable in Python
# - datatype

# %%
1+1
# Out:
# 2

# %%
4*5
# Out:
# 20

# %%
2*10
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10**2
# Out:
# 100

# %% [markdown]
# ## Checck the data Types

# %%
type(1)
# Out:
# int

# %%
type('Masum')
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Strings

# %%
"Hello"
# Out:
# 'Hello'

# %%
'Masum Billah'
# Out:
# 'Masum Billah'

# %%
type('Masum Billah')
# Out:
# str

# %% [markdown]
# ## Variable Assignment

# %% [markdown]
# ### Syntax
# ### var_name= Values

# %%
a=10

# %%
type(a)
# Out:
# int

# %%
a='Masum Billah'

# %%
type(a)
# Out:
# str

# %%
# Mathematical Operation with variable Assignment
a=10
b=20

# %%
print(a*b)
print(a/b)
print(a%b)
print((a*b)+(a/b))
# Out:
# 200
# 0.5
# 10
# 200.5

# %% [markdown]
# ## Various Way of Printing

# %%
print("Hello")
# Out:
# Hello

# %%
firstName='Masum'
lastName='Billah'

# %%
print("My first name is {} and last name is {}".format(firstName,lastName))
# Out:
# My first name is Masum and last name is Billah

# %%
print("My first name is {first} and last name is {last}".format(last=lastName,first=firstName))
# Out:
# My first name is Masum and last name is Billah

# %%
print(f"My first name is {firstName} and lastnme is {lastName}")
# Out:
# My first name is Masum and lastnme is Billah

# %%
len('Masum')
# Out:
# 5
