# %%
# read a whole file and print its contents
with open ('example.txt','r') as file:
    content =file.read()
    print(content)
# Out:
# Hello Masum
# This is a new line.
# append operation
# First line
# Second line
# Third line

# %%
# read file line by line 
with open ('example.txt','r') as file:
    for lines in file:
        print(lines.strip())  # strip() removes leading/trailing whitespace
# Out:
# Hello Masum
# This is a new line.
# append operation
# First line
# Second line
# Third line
