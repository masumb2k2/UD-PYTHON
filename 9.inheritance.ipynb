# %% [markdown]
# # Inheritance in Python

# %%
# parent Class
class Car:
    def __init__(self,windows,doors,engine_type):
        self.windows = windows
        self.doors = doors
        self.engine_type = engine_type
    def drive(self):
        print(f"The car is driving {self.engine_type} car")

# %%
car1=Car(4,4,"Petrol")
car1.drive()
# Out:
# The car is driving Petrol car

# %%
# child class
class Tesla(Car):
    def __init__(self,windows,doors,engine_type,is_selfDriving):
        super ().__init__(windows,doors,engine_type)
        self.is_selfDriving=is_selfDriving
    
    def selfDrivin(self):
        print(f"Tesla Supports selfDriving:{self.is_selfDriving}")

# %%
Tesla1=Tesla(4,5,'Electic',True)
Tesla1.selfDrivin()
# Out:
# Tesla Supports selfDriving:True

# %%
Tesla1.drive()
# Out:
# The car is driving Electic car

# %%
# Multiple inheritance 
# when a class inherits from more than ome base class
# base class 1
class Animal:
    def __init__(self, name):
        self.name=name
    def speak(self):
        print("Subclasses must implement this method")
# base class 2
class pet:
    def __init__(self,owner):
        self.owner=owner

# derived class
class Dog(Animal,pet):
    def __init__(self,name,owner):
        Animal.__init__(self.name)
        pet.__init__(self.owner)
    
    def speak(self):
        return f"{self.name} say woof"
dog=Dog("dora","Masum")
dog.speak()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 22
#      20     def speak(self):
#      21         return f"{self.name} say woof"
# ---> 22 dog=Dog("dora","Masum")
#      23 dog.speak()
#
# Cell In[14], line 17, in Dog.__init__(self, name, owner)
#      16 def __init__(self,name,owner):
# ---> 17     Animal.__init__(self.name)
#      18     pet.__init__(self.owner)
#
# AttributeError: 'Dog' object has no attribute 'name'
